# %% [markdown]
# What is the difference between hardware and software? Give one example of each?
#
# - Hardware is which we can physically touch.
#
# - Software is program that runs on compute and perform tasks based on instructions.
#
# - Kernel will help to act as bridge between physical hardware and software applications.
#
# Hardware Examples: Keyboard, Mouse, CPU, Hardisk, Ram
#
# Software Examples: whatsapp,Paint, Googlenotebook
